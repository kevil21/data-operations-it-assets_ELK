# %% [markdown]
# # This notebook is for cleaning the data

# %% [markdown]
# ### 1. Loading dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/it_asset_inventory_enriched.csv", dtype=str, keep_default_na=False)
print(f"Dataset contains {len(df)} rows")
df.head(5)
# Out:
# Dataset contains 365 rows
#     hostname country operating_system_name operating_system_provider  \
# 0  host-6930      UK            SUSE Linux                    RedHat
# 1  host-6337                  Ubuntu 22.04                    Amazon
# 2  host-5326  BRAZIL              CentOS 7
# 3  host-2279     usa                                          RedHat
# 4  host-8713   INDIA                RHEL 8                    Google
#
#   operating_system_installation_date operating_system_lifecycle_status  \
# 0                         2016-02-10                           Planned
# 1                         2021-11-29                               EOL
# 2                         2010-12-22                               EOS
# 3                         2010-11-02                               EOL
# 4                         2021-10-23                               EOL
#
#   os_is_virtual is_internet_facing image_purpose os_system_id  \
# 0          True                Yes    Production    SYS-30313
# 1          True                 No       Testing    SYS-69014
# 2         False                 No       Testing    SYS-78027
# 3          True                Yes            DR    SYS-88988
# 4         False                Yes            DR    SYS-29294
#
#   performance_score
# 0             55.48
# 1             51.78
# 2             97.43
# 3             94.06
# 4             91.04

# %% [markdown]
# ### 2. Remove duplicates

# %%
before = len(df)
df = df.drop_duplicates(subset=["hostname"], keep="first")
print(f"Removed {before - len(df)} duplicate rows")
# Out:
# Removed 37 duplicate rows

# %% [markdown]
# ### 3. Trim whitespace

# %%
for c in df.columns:
    if pd.api.types.is_string_dtype(df[c]):
        df[c] = df[c].astype(str).str.strip()

# %% [markdown]
# ### 4. Replace empty or NaN with 'Unknown'

# %%
df = df.replace(r"^\s*$", np.nan, regex=True).fillna("Unknown")

# %% [markdown]
# ### 5. Normalize date column

# %%
date_col = "operating_system_installation_date"

parsed = pd.to_datetime(df[date_col], errors="coerce", utc=False, format="mixed")
df[date_col] = parsed.dt.strftime("%Y-%m-%d").fillna("Unknown")

# %% [markdown]
# ### 6. Save cleaned dataset

# %%
df.to_csv("data/it_asset_inventory_cleaned.csv", index=False)
print(f"Saved cleaned CSV to: data/it_asset_inventory_cleaned.csv")
# Out:
# Saved cleaned CSV to: data/it_asset_inventory_cleaned.csv
